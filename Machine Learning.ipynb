# %%
import sys
# !{sys.executable} -m pip install seaborn
# !{sys.executable} -m pip install scikit-learn
# !{sys.executable} -m pip install imblearn
# !{sys.executable} -m pip install ydata-profiling

# %%
import os

# Data Handeling
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import all_estimators
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix
from sklearn import tree
from sklearn.metrics import f1_score, precision_score, recall_score

# Options
# %matplotlib inline
pd.set_option('display.max_columns', None)
sns.set_theme()
pd.set_option('display.float_format', '{:.3f}'.format)

# Initializing Result DataFrame
result_df = pd.DataFrame(columns=['Model', 'Model Type', 'Train Accuracy', 'Test Accuracy', 'Precision', 'Recall', 'F1', 'Data Type', 'Settings'])
best_df = pd.DataFrame(columns=['Model', 'Model Type', 'Accuracy', 'Precision', 'Recall', 'F1', 'Data Type', 'Settings'])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import CategoricalNB
from sklearn.multioutput import ClassifierChain
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC

# %%
df_sample = pd.read_pickle('./Datasets/flight_dataset_sample_small.pkl')

df_sample_enc = pd.get_dummies(df_sample, columns=['DEP_TIME_BLK', 'ARR_TIME_BLK'])
                               
enc = LabelEncoder()

selected_columns = ['TAIL_NUM', 'DEPARTING_AIRPORT', 'CARRIER_NAME', 'PREVIOUS_AIRPORT']

for column in selected_columns:
    df_sample_enc[column] = enc.fit_transform(df_sample_enc[column])

# %%
X_enc = df_sample_enc.drop('DEP_DEL15', axis=1)
y_enc = df_sample_enc['DEP_DEL15']

X_train_enc, X_test_enc, y_train_enc, y_test_enc = train_test_split(X_enc, y_enc, test_size=0.20, random_state=68, stratify=y_enc)

# %%
df_sample_hot = pd.get_dummies(df_sample, columns=['DEP_TIME_BLK', 'ARR_TIME_BLK', 'TAIL_NUM', 'DEPARTING_AIRPORT', 'CARRIER_NAME', 'PREVIOUS_AIRPORT'])

X_hot = df_sample_hot.drop('DEP_DEL15', axis=1)
y_hot = df_sample_hot['DEP_DEL15']

X_train_hot, X_test_hot, y_train_hot, y_test_hot = train_test_split(X_hot, y_hot, test_size=0.20, random_state=68, stratify=y_hot)

# %%
dC = DummyClassifier(strategy="most_frequent", random_state=68)
dC.fit(X_train_enc, y_train_enc)
print(dC.score(X_test_enc, y_test_enc))
# Out:
# 0.81085

# %%
from sklearn.pipeline import make_pipeline

# %%
labels = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
categories = ['Not Delayed', 'Delayed']

def make_confusion_matrix(cf, group_names=None, categories='auto', count=True, percent=True, cbar=True, xyticks=True, xyplotlabels=True, sum_stats=True, figsize=None, cmap='Blues', title=None, model=None, model_type=None, params=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    ---------
    cf:            confusion matrix to be passed in
    group_names:   List of strings that represent the labels row by row to be shown in each square.
    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'
    count:         If True, show the raw number in the confusion matrix. Default is True.
    normalize:     If True, show the proportions for each category. Default is True.
    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.
    xyticks:       If True, show x and y ticks. Default is True.
    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.
    sum_stats:     If True, display summary statistics below the figure. Default is True.
    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.
    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html
                   
    title:         Title for the heatmap. Default is None.
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}\n\nParams:\n{}".format(
                accuracy,precision,recall,f1_score,params)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('Actual label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)
    
    if title:
        full_title = model + ' - ' + title
        
        plt.title(full_title)
        
    folderstr = './cm/' + model_type + '/' + model
    
    if not os.path.exists(folderstr):
        os.makedirs(folderstr)
        
    savestr = folderstr + '/' + title + '.png'
        
    plt.savefig(savestr, bbox_inches='tight')

# %%
# The scoring methods that needs to be calculated
scoring = {'accuracy': 'accuracy', 'precision': 'precision', 'recall': 'recall', 'f1': 'f1'}

# The different parameters that should be searched by GridSearchCV
param_grid = {
    'kneighborsclassifier__weights': ['uniform', 'distance'],
    'kneighborsclassifier__n_neighbors': list(range(1, 15, 2)),
    'kneighborsclassifier__metric': ['manhattan', 'euclidean', 'hamming', 'minkowski', 'chebyshev']
}

# Our pipeline that first scales the data without leakage and then fits the model
model = make_pipeline(StandardScaler(), KNeighborsClassifier())

# The grid is build. We are using f1 as our selection method
grid = GridSearchCV(model, param_grid, cv=3, refit='f1', scoring=scoring, return_train_score=True, verbose=3)

# We are fitting the training data
grid.fit(X_train_enc, y_train_enc)

# We are doing a prediction on our test data (used for confusion matrix)
y_pred = grid.predict(X_test_enc)

# Confusion matrix is generated based on the predictions and the actual labels
cm = confusion_matrix(y_test_enc, y_pred, labels=grid.classes_)

# Utilizing a customized function of previous work: https://github.com/DTrimarchi10/confusion_matrix
make_confusion_matrix(cm, group_names=labels, categories=categories, title='Tuned and Scaled', model='KNeighborsClassifier', model_type='neighbors', params=grid.best_params_)

# Generating Different Metrics
print(f'True Positives: {cm[1][1]}')
print(f'False Positives: {cm[0][1]}')
print(f'Training Accuracy: {grid.best_estimator_.score(X_train_enc, y_train_enc):.4f}')
print(f'Testing Accuracy: {grid.best_estimator_.score(X_test_enc, y_test_enc):.4f}')
print(f'Precision: {precision_score(y_test_enc, y_pred):.4f}')
print(f'Recall: {recall_score(y_test_enc, y_pred):.4f}')
print(f'F1: {f1_score(y_test_enc, y_pred):.4f}')
# Out:
# Fitting 3 folds for each of 70 candidates, totalling 210 fits
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.722) f1: (train=1.000, test=0.248) precision: (train=1.000, test=0.254) recall: (train=1.000, test=0.242) total time=   7.5s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.722) f1: (train=1.000, test=0.247) precision: (train=1.000, test=0.254) recall: (train=1.000, test=0.241) total time=   7.5s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.721) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.248) recall: (train=1.000, test=0.234) total time=   7.5s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.722) f1: (train=1.000, test=0.248) precision: (train=1.000, test=0.254) recall: (train=1.000, test=0.242) total time=   7.1s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.722) f1: (train=1.000, test=0.247) precision: (train=1.000, test=0.254) recall: (train=1.000, test=0.241) total time=   7.2s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.721) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.248) recall: (train=1.000, test=0.234) total time=   7.0s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.858, test=0.768) f1: (train=0.520, test=0.190) precision: (train=0.724, test=0.281) recall: (train=0.405, test=0.144) total time=   7.8s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.859, test=0.767) f1: (train=0.520, test=0.196) precision: (train=0.729, test=0.283) recall: (train=0.404, test=0.150) total time=   7.5s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.860, test=0.766) f1: (train=0.525, test=0.196) precision: (train=0.732, test=0.281) recall: (train=0.409, test=0.151) total time=   7.8s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.764) f1: (train=1.000, test=0.198) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.154) total time=   7.2s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.764) f1: (train=1.000, test=0.204) precision: (train=1.000, test=0.281) recall: (train=1.000, test=0.160) total time=   7.2s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.762) f1: (train=1.000, test=0.204) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.161) total time=   7.2s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.835, test=0.785) f1: (train=0.359, test=0.151) precision: (train=0.675, test=0.298) recall: (train=0.245, test=0.101) total time=   7.7s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.833, test=0.786) f1: (train=0.347, test=0.153) precision: (train=0.664, test=0.306) recall: (train=0.235, test=0.102) total time=   7.5s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.835, test=0.784) f1: (train=0.360, test=0.149) precision: (train=0.670, test=0.293) recall: (train=0.246, test=0.100) total time=   7.8s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.781) f1: (train=1.000, test=0.160) precision: (train=1.000, test=0.291) recall: (train=1.000, test=0.110) total time=   7.2s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.782) f1: (train=1.000, test=0.163) precision: (train=1.000, test=0.298) recall: (train=1.000, test=0.112) total time=   7.0s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.781) f1: (train=1.000, test=0.162) precision: (train=1.000, test=0.291) recall: (train=1.000, test=0.112) total time=   7.2s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.794) f1: (train=0.253, test=0.112) precision: (train=0.648, test=0.301) recall: (train=0.157, test=0.069) total time=   8.0s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.823, test=0.795) f1: (train=0.253, test=0.120) precision: (train=0.633, test=0.317) recall: (train=0.158, test=0.074) total time=   7.9s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.825, test=0.794) f1: (train=0.255, test=0.113) precision: (train=0.647, test=0.304) recall: (train=0.159, test=0.069) total time=   7.9s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.791) f1: (train=1.000, test=0.125) precision: (train=1.000, test=0.297) recall: (train=1.000, test=0.079) total time=   7.3s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.792) f1: (train=1.000, test=0.133) precision: (train=1.000, test=0.313) recall: (train=1.000, test=0.084) total time=   7.2s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.790) f1: (train=1.000, test=0.129) precision: (train=1.000, test=0.302) recall: (train=1.000, test=0.082) total time=   7.3s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.799) f1: (train=0.189, test=0.087) precision: (train=0.632, test=0.309) recall: (train=0.111, test=0.050) total time=   7.8s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.801) f1: (train=0.195, test=0.097) precision: (train=0.641, test=0.338) recall: (train=0.115, test=0.057) total time=   8.0s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.819, test=0.800) f1: (train=0.187, test=0.098) precision: (train=0.625, test=0.331) recall: (train=0.110, test=0.057) total time=   8.0s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.796) f1: (train=1.000, test=0.100) precision: (train=1.000, test=0.303) recall: (train=1.000, test=0.060) total time=   7.2s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.111) precision: (train=1.000, test=0.334) recall: (train=1.000, test=0.067) total time=   7.2s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.797) f1: (train=1.000, test=0.110) precision: (train=1.000, test=0.321) recall: (train=1.000, test=0.066) total time=   7.2s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.802) f1: (train=0.144, test=0.075) precision: (train=0.623, test=0.322) recall: (train=0.081, test=0.042) total time=   7.8s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.803) f1: (train=0.147, test=0.074) precision: (train=0.626, test=0.338) recall: (train=0.083, test=0.042) total time=   7.7s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.803) f1: (train=0.141, test=0.079) precision: (train=0.608, test=0.346) recall: (train=0.080, test=0.044) total time=   7.9s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.800) f1: (train=1.000, test=0.084) precision: (train=1.000, test=0.310) recall: (train=1.000, test=0.049) total time=   7.3s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.801) f1: (train=1.000, test=0.089) precision: (train=1.000, test=0.333) recall: (train=1.000, test=0.051) total time=   7.2s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.800) f1: (train=1.000, test=0.090) precision: (train=1.000, test=0.322) recall: (train=1.000, test=0.053) total time=   7.4s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.113, test=0.063) precision: (train=0.627, test=0.359) recall: (train=0.062, test=0.034) total time=   7.8s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.115, test=0.059) precision: (train=0.629, test=0.349) recall: (train=0.063, test=0.032) total time=   7.7s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.815, test=0.807) f1: (train=0.108, test=0.069) precision: (train=0.617, test=0.389) recall: (train=0.059, test=0.038) total time=   7.8s
# [CV 1/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.074) precision: (train=1.000, test=0.339) recall: (train=1.000, test=0.041) total time=   7.4s
# [CV 2/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.071) precision: (train=1.000, test=0.338) recall: (train=1.000, test=0.040) total time=   7.3s
# [CV 3/3] END kneighborsclassifier__metric=manhattan, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.078) precision: (train=1.000, test=0.351) recall: (train=1.000, test=0.044) total time=   7.3s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.717) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.244) recall: (train=1.000, test=0.237) total time=   1.8s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.720) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.251) recall: (train=1.000, test=0.242) total time=   1.5s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.718) f1: (train=1.000, test=0.242) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.238) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.717) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.244) recall: (train=1.000, test=0.237) total time=   1.0s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.720) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.251) recall: (train=1.000, test=0.242) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.718) f1: (train=1.000, test=0.242) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.238) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.857, test=0.767) f1: (train=0.517, test=0.194) precision: (train=0.715, test=0.280) recall: (train=0.405, test=0.148) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.858, test=0.765) f1: (train=0.517, test=0.199) precision: (train=0.721, test=0.280) recall: (train=0.403, test=0.155) total time=   1.6s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.859, test=0.765) f1: (train=0.527, test=0.202) precision: (train=0.723, test=0.283) recall: (train=0.415, test=0.157) total time=   1.5s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.764) f1: (train=1.000, test=0.198) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.153) total time=   1.0s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.762) f1: (train=1.000, test=0.203) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.160) total time=   1.0s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.762) f1: (train=1.000, test=0.203) precision: (train=1.000, test=0.277) recall: (train=1.000, test=0.160) total time=   1.0s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.834, test=0.785) f1: (train=0.354, test=0.155) precision: (train=0.669, test=0.303) recall: (train=0.241, test=0.104) total time=   1.9s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.833, test=0.785) f1: (train=0.352, test=0.156) precision: (train=0.659, test=0.301) recall: (train=0.240, test=0.105) total time=   1.6s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.833, test=0.783) f1: (train=0.356, test=0.160) precision: (train=0.659, test=0.300) recall: (train=0.244, test=0.109) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.783) f1: (train=1.000, test=0.164) precision: (train=1.000, test=0.303) recall: (train=1.000, test=0.112) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.782) f1: (train=1.000, test=0.161) precision: (train=1.000, test=0.297) recall: (train=1.000, test=0.110) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.781) f1: (train=1.000, test=0.163) precision: (train=1.000, test=0.294) recall: (train=1.000, test=0.113) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.825, test=0.795) f1: (train=0.256, test=0.126) precision: (train=0.650, test=0.327) recall: (train=0.159, test=0.078) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.794) f1: (train=0.259, test=0.122) precision: (train=0.631, test=0.316) recall: (train=0.163, test=0.076) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.793) f1: (train=0.266, test=0.127) precision: (train=0.634, test=0.311) recall: (train=0.169, test=0.080) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.793) f1: (train=1.000, test=0.133) precision: (train=1.000, test=0.321) recall: (train=1.000, test=0.084) total time=   1.4s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.793) f1: (train=1.000, test=0.131) precision: (train=1.000, test=0.316) recall: (train=1.000, test=0.082) total time=   1.2s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.790) f1: (train=1.000, test=0.131) precision: (train=1.000, test=0.303) recall: (train=1.000, test=0.084) total time=   1.2s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.801) f1: (train=0.192, test=0.105) precision: (train=0.643, test=0.355) recall: (train=0.113, test=0.062) total time=   1.8s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.800) f1: (train=0.203, test=0.101) precision: (train=0.633, test=0.340) recall: (train=0.121, test=0.059) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.821, test=0.800) f1: (train=0.202, test=0.105) precision: (train=0.635, test=0.338) recall: (train=0.120, test=0.062) total time=   1.7s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.800) f1: (train=1.000, test=0.111) precision: (train=1.000, test=0.348) recall: (train=1.000, test=0.066) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.799) f1: (train=1.000, test=0.108) precision: (train=1.000, test=0.338) recall: (train=1.000, test=0.064) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.112) precision: (train=1.000, test=0.330) recall: (train=1.000, test=0.067) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.805) f1: (train=0.153, test=0.088) precision: (train=0.637, test=0.382) recall: (train=0.087, test=0.050) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.804) f1: (train=0.157, test=0.081) precision: (train=0.632, test=0.355) recall: (train=0.090, test=0.046) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.804) f1: (train=0.152, test=0.089) precision: (train=0.614, test=0.367) recall: (train=0.087, test=0.051) total time=   1.8s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.092) precision: (train=1.000, test=0.366) recall: (train=1.000, test=0.053) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.088) precision: (train=1.000, test=0.350) recall: (train=1.000, test=0.050) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.095) precision: (train=1.000, test=0.357) recall: (train=1.000, test=0.055) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.121, test=0.069) precision: (train=0.622, test=0.377) recall: (train=0.067, test=0.038) total time=   1.7s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.805) f1: (train=0.129, test=0.067) precision: (train=0.624, test=0.348) recall: (train=0.072, test=0.037) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.121, test=0.075) precision: (train=0.627, test=0.380) recall: (train=0.067, test=0.042) total time=   1.7s
# [CV 1/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.074) precision: (train=1.000, test=0.361) recall: (train=1.000, test=0.041) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.073) precision: (train=1.000, test=0.355) recall: (train=1.000, test=0.041) total time=   1.2s
# [CV 3/3] END kneighborsclassifier__metric=euclidean, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.082) precision: (train=1.000, test=0.368) recall: (train=1.000, test=0.046) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.725) f1: (train=1.000, test=0.261) precision: (train=1.000, test=0.265) recall: (train=1.000, test=0.257) total time= 1.5min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.725) f1: (train=1.000, test=0.253) precision: (train=1.000, test=0.260) recall: (train=1.000, test=0.246) total time= 1.5min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.723) f1: (train=1.000, test=0.256) precision: (train=1.000, test=0.261) recall: (train=1.000, test=0.252) total time= 1.6min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.725) f1: (train=1.000, test=0.261) precision: (train=1.000, test=0.265) recall: (train=1.000, test=0.257) total time= 1.6min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.725) f1: (train=1.000, test=0.253) precision: (train=1.000, test=0.260) recall: (train=1.000, test=0.246) total time= 1.6min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.723) f1: (train=1.000, test=0.256) precision: (train=1.000, test=0.261) recall: (train=1.000, test=0.252) total time= 1.5min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.864, test=0.772) f1: (train=0.544, test=0.209) precision: (train=0.743, test=0.304) recall: (train=0.429, test=0.159) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.864, test=0.769) f1: (train=0.545, test=0.194) precision: (train=0.746, test=0.286) recall: (train=0.429, test=0.147) total time= 1.6min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.862, test=0.771) f1: (train=0.534, test=0.202) precision: (train=0.742, test=0.297) recall: (train=0.417, test=0.153) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.771) f1: (train=1.000, test=0.211) precision: (train=1.000, test=0.304) recall: (train=1.000, test=0.162) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.768) f1: (train=1.000, test=0.195) precision: (train=1.000, test=0.284) recall: (train=1.000, test=0.148) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.770) f1: (train=1.000, test=0.203) precision: (train=1.000, test=0.295) recall: (train=1.000, test=0.155) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.840, test=0.791) f1: (train=0.379, test=0.159) precision: (train=0.710, test=0.334) recall: (train=0.258, test=0.104) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.838, test=0.791) f1: (train=0.365, test=0.163) precision: (train=0.705, test=0.338) recall: (train=0.246, test=0.107) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.837, test=0.790) f1: (train=0.361, test=0.160) precision: (train=0.698, test=0.327) recall: (train=0.244, test=0.106) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.790) f1: (train=1.000, test=0.160) precision: (train=1.000, test=0.327) recall: (train=1.000, test=0.106) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.790) f1: (train=1.000, test=0.163) precision: (train=1.000, test=0.333) recall: (train=1.000, test=0.108) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.789) f1: (train=1.000, test=0.165) precision: (train=1.000, test=0.329) recall: (train=1.000, test=0.110) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.827, test=0.798) f1: (train=0.266, test=0.119) precision: (train=0.681, test=0.342) recall: (train=0.166, test=0.072) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.827, test=0.800) f1: (train=0.261, test=0.126) precision: (train=0.685, test=0.359) recall: (train=0.161, test=0.077) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.828, test=0.799) f1: (train=0.262, test=0.126) precision: (train=0.697, test=0.357) recall: (train=0.161, test=0.077) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.797) f1: (train=1.000, test=0.123) precision: (train=1.000, test=0.340) recall: (train=1.000, test=0.075) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.799) f1: (train=1.000, test=0.129) precision: (train=1.000, test=0.355) recall: (train=1.000, test=0.079) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.126) precision: (train=1.000, test=0.345) recall: (train=1.000, test=0.077) total time= 1.8min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.823, test=0.803) f1: (train=0.201, test=0.091) precision: (train=0.695, test=0.356) recall: (train=0.118, test=0.052) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.822, test=0.803) f1: (train=0.197, test=0.096) precision: (train=0.678, test=0.367) recall: (train=0.115, test=0.055) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.822, test=0.805) f1: (train=0.194, test=0.094) precision: (train=0.686, test=0.381) recall: (train=0.113, test=0.054) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.802) f1: (train=1.000, test=0.098) precision: (train=1.000, test=0.359) recall: (train=1.000, test=0.057) total time= 1.6min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.100) precision: (train=1.000, test=0.365) recall: (train=1.000, test=0.058) total time= 1.8min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.095) precision: (train=1.000, test=0.363) recall: (train=1.000, test=0.055) total time= 1.6min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.807) f1: (train=0.151, test=0.078) precision: (train=0.696, test=0.396) recall: (train=0.085, test=0.043) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.819, test=0.806) f1: (train=0.148, test=0.076) precision: (train=0.679, test=0.391) recall: (train=0.083, test=0.042) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.819, test=0.807) f1: (train=0.145, test=0.078) precision: (train=0.674, test=0.401) recall: (train=0.081, test=0.043) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.806) f1: (train=1.000, test=0.083) precision: (train=1.000, test=0.397) recall: (train=1.000, test=0.046) total time= 1.7min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.807) f1: (train=1.000, test=0.082) precision: (train=1.000, test=0.402) recall: (train=1.000, test=0.046) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.806) f1: (train=1.000, test=0.079) precision: (train=1.000, test=0.389) recall: (train=1.000, test=0.044) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.808) f1: (train=0.108, test=0.063) precision: (train=0.675, test=0.415) recall: (train=0.059, test=0.034) total time= 1.8min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.808) f1: (train=0.114, test=0.055) precision: (train=0.679, test=0.386) recall: (train=0.062, test=0.030) total time= 1.8min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.808) f1: (train=0.111, test=0.063) precision: (train=0.681, test=0.418) recall: (train=0.060, test=0.034) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.808) f1: (train=1.000, test=0.066) precision: (train=1.000, test=0.420) recall: (train=1.000, test=0.036) total time= 1.8min
# [CV 2/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.808) f1: (train=1.000, test=0.060) precision: (train=1.000, test=0.400) recall: (train=1.000, test=0.033) total time= 1.7min
# [CV 3/3] END kneighborsclassifier__metric=hamming, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.808) f1: (train=1.000, test=0.065) precision: (train=1.000, test=0.413) recall: (train=1.000, test=0.035) total time= 1.7min
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.717) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.244) recall: (train=1.000, test=0.237) total time=   1.5s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.720) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.251) recall: (train=1.000, test=0.242) total time=   1.6s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.718) f1: (train=1.000, test=0.242) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.238) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.717) f1: (train=1.000, test=0.241) precision: (train=1.000, test=0.244) recall: (train=1.000, test=0.237) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.720) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.251) recall: (train=1.000, test=0.242) total time=   1.0s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.718) f1: (train=1.000, test=0.242) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.238) total time=   1.0s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.857, test=0.767) f1: (train=0.517, test=0.194) precision: (train=0.715, test=0.280) recall: (train=0.405, test=0.148) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.858, test=0.765) f1: (train=0.517, test=0.199) precision: (train=0.721, test=0.280) recall: (train=0.403, test=0.155) total time=   1.6s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.859, test=0.765) f1: (train=0.527, test=0.202) precision: (train=0.723, test=0.283) recall: (train=0.415, test=0.157) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.764) f1: (train=1.000, test=0.198) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.153) total time=   1.0s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.762) f1: (train=1.000, test=0.203) precision: (train=1.000, test=0.278) recall: (train=1.000, test=0.160) total time=   1.0s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.762) f1: (train=1.000, test=0.203) precision: (train=1.000, test=0.277) recall: (train=1.000, test=0.160) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.834, test=0.785) f1: (train=0.354, test=0.155) precision: (train=0.669, test=0.303) recall: (train=0.241, test=0.104) total time=   1.7s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.833, test=0.785) f1: (train=0.352, test=0.156) precision: (train=0.659, test=0.301) recall: (train=0.240, test=0.105) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.833, test=0.783) f1: (train=0.356, test=0.160) precision: (train=0.659, test=0.300) recall: (train=0.244, test=0.109) total time=   1.6s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.783) f1: (train=1.000, test=0.164) precision: (train=1.000, test=0.303) recall: (train=1.000, test=0.112) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.782) f1: (train=1.000, test=0.161) precision: (train=1.000, test=0.297) recall: (train=1.000, test=0.110) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.781) f1: (train=1.000, test=0.163) precision: (train=1.000, test=0.294) recall: (train=1.000, test=0.113) total time=   1.0s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.825, test=0.795) f1: (train=0.256, test=0.126) precision: (train=0.650, test=0.327) recall: (train=0.159, test=0.078) total time=   1.7s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.794) f1: (train=0.259, test=0.122) precision: (train=0.631, test=0.316) recall: (train=0.163, test=0.076) total time=   1.6s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.793) f1: (train=0.266, test=0.127) precision: (train=0.634, test=0.311) recall: (train=0.169, test=0.080) total time=   1.7s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.793) f1: (train=1.000, test=0.133) precision: (train=1.000, test=0.321) recall: (train=1.000, test=0.084) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.793) f1: (train=1.000, test=0.131) precision: (train=1.000, test=0.316) recall: (train=1.000, test=0.082) total time=   1.0s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.790) f1: (train=1.000, test=0.131) precision: (train=1.000, test=0.303) recall: (train=1.000, test=0.084) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.801) f1: (train=0.192, test=0.105) precision: (train=0.643, test=0.355) recall: (train=0.113, test=0.062) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.820, test=0.800) f1: (train=0.203, test=0.101) precision: (train=0.633, test=0.340) recall: (train=0.121, test=0.059) total time=   1.8s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.821, test=0.800) f1: (train=0.202, test=0.105) precision: (train=0.635, test=0.338) recall: (train=0.120, test=0.062) total time=   1.8s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.800) f1: (train=1.000, test=0.111) precision: (train=1.000, test=0.348) recall: (train=1.000, test=0.066) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.799) f1: (train=1.000, test=0.108) precision: (train=1.000, test=0.338) recall: (train=1.000, test=0.064) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.112) precision: (train=1.000, test=0.330) recall: (train=1.000, test=0.067) total time=   1.1s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.805) f1: (train=0.153, test=0.088) precision: (train=0.637, test=0.382) recall: (train=0.087, test=0.050) total time=   1.6s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.804) f1: (train=0.157, test=0.081) precision: (train=0.632, test=0.355) recall: (train=0.090, test=0.046) total time=   1.9s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.804) f1: (train=0.152, test=0.089) precision: (train=0.614, test=0.367) recall: (train=0.087, test=0.051) total time=   1.7s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.092) precision: (train=1.000, test=0.366) recall: (train=1.000, test=0.053) total time=   1.1s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.088) precision: (train=1.000, test=0.350) recall: (train=1.000, test=0.050) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.803) f1: (train=1.000, test=0.095) precision: (train=1.000, test=0.357) recall: (train=1.000, test=0.055) total time=   1.2s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.121, test=0.069) precision: (train=0.622, test=0.377) recall: (train=0.067, test=0.038) total time=   1.7s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.805) f1: (train=0.129, test=0.067) precision: (train=0.624, test=0.348) recall: (train=0.072, test=0.037) total time=   1.7s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.806) f1: (train=0.121, test=0.075) precision: (train=0.627, test=0.380) recall: (train=0.067, test=0.042) total time=   1.8s
# [CV 1/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.074) precision: (train=1.000, test=0.361) recall: (train=1.000, test=0.041) total time=   1.2s
# [CV 2/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.073) precision: (train=1.000, test=0.355) recall: (train=1.000, test=0.041) total time=   1.1s
# [CV 3/3] END kneighborsclassifier__metric=minkowski, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.805) f1: (train=1.000, test=0.082) precision: (train=1.000, test=0.368) recall: (train=1.000, test=0.046) total time=   1.2s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.715) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.245) total time=   5.9s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.711) f1: (train=1.000, test=0.232) precision: (train=1.000, test=0.234) recall: (train=1.000, test=0.231) total time=   6.2s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=uniform; accuracy: (train=1.000, test=0.714) f1: (train=1.000, test=0.239) precision: (train=1.000, test=0.240) recall: (train=1.000, test=0.237) total time=   6.1s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.715) f1: (train=1.000, test=0.246) precision: (train=1.000, test=0.246) recall: (train=1.000, test=0.245) total time=   5.6s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.711) f1: (train=1.000, test=0.232) precision: (train=1.000, test=0.234) recall: (train=1.000, test=0.231) total time=   5.5s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=1, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.714) f1: (train=1.000, test=0.239) precision: (train=1.000, test=0.240) recall: (train=1.000, test=0.237) total time=   5.5s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.853, test=0.766) f1: (train=0.505, test=0.201) precision: (train=0.699, test=0.283) recall: (train=0.395, test=0.155) total time=   6.1s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.855, test=0.761) f1: (train=0.510, test=0.189) precision: (train=0.705, test=0.264) recall: (train=0.400, test=0.147) total time=   6.1s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=uniform; accuracy: (train=0.856, test=0.759) f1: (train=0.517, test=0.191) precision: (train=0.711, test=0.262) recall: (train=0.406, test=0.151) total time=   6.2s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.765) f1: (train=1.000, test=0.204) precision: (train=1.000, test=0.283) recall: (train=1.000, test=0.159) total time=   5.6s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.760) f1: (train=1.000, test=0.191) precision: (train=1.000, test=0.264) recall: (train=1.000, test=0.150) total time=   5.6s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=3, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.758) f1: (train=1.000, test=0.194) precision: (train=1.000, test=0.261) recall: (train=1.000, test=0.154) total time=   5.6s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.830, test=0.785) f1: (train=0.340, test=0.169) precision: (train=0.641, test=0.316) recall: (train=0.232, test=0.115) total time=   6.1s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.832, test=0.781) f1: (train=0.354, test=0.155) precision: (train=0.647, test=0.287) recall: (train=0.243, test=0.106) total time=   6.1s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=uniform; accuracy: (train=0.831, test=0.778) f1: (train=0.355, test=0.156) precision: (train=0.640, test=0.276) recall: (train=0.245, test=0.108) total time=   6.1s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.784) f1: (train=1.000, test=0.171) precision: (train=1.000, test=0.312) recall: (train=1.000, test=0.118) total time=   5.6s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.780) f1: (train=1.000, test=0.158) precision: (train=1.000, test=0.286) recall: (train=1.000, test=0.109) total time=   5.6s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=5, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.777) f1: (train=1.000, test=0.159) precision: (train=1.000, test=0.276) recall: (train=1.000, test=0.111) total time=   5.6s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.822, test=0.794) f1: (train=0.249, test=0.127) precision: (train=0.620, test=0.320) recall: (train=0.155, test=0.080) total time=   6.1s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.791) f1: (train=0.265, test=0.127) precision: (train=0.626, test=0.303) recall: (train=0.168, test=0.080) total time=   6.2s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=uniform; accuracy: (train=0.824, test=0.789) f1: (train=0.266, test=0.130) precision: (train=0.624, test=0.293) recall: (train=0.169, test=0.083) total time=   6.1s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.793) f1: (train=1.000, test=0.132) precision: (train=1.000, test=0.319) recall: (train=1.000, test=0.083) total time=   5.7s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.791) f1: (train=1.000, test=0.132) precision: (train=1.000, test=0.306) recall: (train=1.000, test=0.084) total time=   5.6s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=7, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.787) f1: (train=1.000, test=0.133) precision: (train=1.000, test=0.289) recall: (train=1.000, test=0.086) total time=   5.4s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.817, test=0.799) f1: (train=0.188, test=0.105) precision: (train=0.592, test=0.330) recall: (train=0.112, test=0.062) total time=   6.1s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.798) f1: (train=0.198, test=0.106) precision: (train=0.595, test=0.322) recall: (train=0.119, test=0.063) total time=   6.1s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=uniform; accuracy: (train=0.818, test=0.795) f1: (train=0.202, test=0.106) precision: (train=0.599, test=0.305) recall: (train=0.121, test=0.064) total time=   6.0s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.109) precision: (train=1.000, test=0.328) recall: (train=1.000, test=0.065) total time=   5.6s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.797) f1: (train=1.000, test=0.110) precision: (train=1.000, test=0.322) recall: (train=1.000, test=0.067) total time=   5.7s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=9, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.794) f1: (train=1.000, test=0.109) precision: (train=1.000, test=0.300) recall: (train=1.000, test=0.066) total time=   5.7s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.815, test=0.801) f1: (train=0.142, test=0.080) precision: (train=0.571, test=0.322) recall: (train=0.081, test=0.046) total time=   6.2s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.816, test=0.801) f1: (train=0.159, test=0.087) precision: (train=0.592, test=0.333) recall: (train=0.092, test=0.050) total time=   6.2s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=uniform; accuracy: (train=0.815, test=0.799) f1: (train=0.158, test=0.091) precision: (train=0.576, test=0.317) recall: (train=0.092, test=0.053) total time=   6.2s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.801) f1: (train=1.000, test=0.086) precision: (train=1.000, test=0.325) recall: (train=1.000, test=0.049) total time=   5.5s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.801) f1: (train=1.000, test=0.088) precision: (train=1.000, test=0.329) recall: (train=1.000, test=0.051) total time=   5.6s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=11, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.798) f1: (train=1.000, test=0.094) precision: (train=1.000, test=0.313) recall: (train=1.000, test=0.056) total time=   5.6s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.814, test=0.804) f1: (train=0.113, test=0.077) precision: (train=0.567, test=0.359) recall: (train=0.063, test=0.043) total time=   6.2s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.814, test=0.805) f1: (train=0.130, test=0.079) precision: (train=0.572, test=0.364) recall: (train=0.073, test=0.044) total time=   6.1s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=uniform; accuracy: (train=0.814, test=0.802) f1: (train=0.131, test=0.075) precision: (train=0.571, test=0.322) recall: (train=0.074, test=0.042) total time=   6.2s
# [CV 1/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.079) precision: (train=1.000, test=0.356) recall: (train=1.000, test=0.045) total time=   5.6s
# [CV 2/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.804) f1: (train=1.000, test=0.079) precision: (train=1.000, test=0.357) recall: (train=1.000, test=0.045) total time=   5.5s
# [CV 3/3] END kneighborsclassifier__metric=chebyshev, kneighborsclassifier__n_neighbors=13, kneighborsclassifier__weights=distance; accuracy: (train=1.000, test=0.801) f1: (train=1.000, test=0.075) precision: (train=1.000, test=0.311) recall: (train=1.000, test=0.043) total time=   5.7s
# True Positives: 1002
# False Positives: 2668
# Training Accuracy: 1.0000
# Testing Accuracy: 0.7276
# Precision: 0.2730
# Recall: 0.2649
# F1: 0.2689

# %%
grid.best_params_
# Out:
# {'kneighborsclassifier__metric': 'hamming',
#  'kneighborsclassifier__n_neighbors': 1,
#  'kneighborsclassifier__weights': 'uniform'}

# %%
cv_results_df = pd.DataFrame(grid.cv_results_)
        
for index, row in cv_results_df.iterrows():
    result_df.loc[len(result_df)] = ['DecisionTreeClassifier', 'tree', row['mean_train_accuracy'], row['mean_test_accuracy'], row['mean_test_precision'], row['mean_test_recall'], row['mean_test_f1'], 'ONE-HOT ENCODING', row['params']]

result_df.to_pickle('model_results/KNearestNeighbor.pkl')

# %%
data = list(zip(X_train_hot.columns.to_list(), grid.best_estimator_.feature_importances_))

feature_df = pd.DataFrame(data, columns=['Features', 'Feature Importance'])

# %%
feature_df = feature_df.sort_values(by='Feature Importance', axis=0, ascending=False).head(15)

feature_df.to_pickle('model_results/RandomForestClassifier_Features.pkl')

# %%
feature_df
# Out:
#                          Features  Feature Importance
# 18                           AWND               0.040
# 17                           TMAX               0.039
# 4              CONCURRENT_FLIGHTS               0.035
# 6           AIRPORT_FLIGHTS_MONTH               0.033
# 8   AIRLINE_AIRPORT_FLIGHTS_MONTH               0.032
# 14                           PRCP               0.029
# 2                 DEST_AIRPORT_ID               0.028
# 7           AIRLINE_FLIGHTS_MONTH               0.028
# 13                      PLANE_AGE               0.027
# 1                     DAY_OF_WEEK               0.026
# 0                           MONTH               0.024
# 3                  DISTANCE_GROUP               0.021
# 9        AVG_MONTHLY_PASS_AIRPORT               0.021
# 5                 NUMBER_OF_SEATS               0.021
# 10       AVG_MONTHLY_PASS_AIRLINE               0.009

# %%
feature_df.style.background_gradient(subset='Feature Importance')
# Out:
# <style type="text/css">
# #T_b0715_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b0715_row1_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_b0715_row2_col1 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_b0715_row3_col1 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_b0715_row4_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_b0715_row5_col1 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_b0715_row6_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_b0715_row7_col1 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_b0715_row8_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_b0715_row9_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_b0715_row10_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_b0715_row11_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_b0715_row12_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_b0715_row13_col1 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_b0715_row14_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_b0715">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0715_level0_col0" class="col_heading level0 col0" >Features</th>
#       <th id="T_b0715_level0_col1" class="col_heading level0 col1" >Feature Importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0715_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_b0715_row0_col0" class="data row0 col0" >AWND</td>
#       <td id="T_b0715_row0_col1" class="data row0 col1" >0.040298</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_b0715_row1_col0" class="data row1 col0" >TMAX</td>
#       <td id="T_b0715_row1_col1" class="data row1 col1" >0.038707</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b0715_row2_col0" class="data row2 col0" >CONCURRENT_FLIGHTS</td>
#       <td id="T_b0715_row2_col1" class="data row2 col1" >0.035346</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_b0715_row3_col0" class="data row3 col0" >AIRPORT_FLIGHTS_MONTH</td>
#       <td id="T_b0715_row3_col1" class="data row3 col1" >0.033227</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_b0715_row4_col0" class="data row4 col0" >AIRLINE_AIRPORT_FLIGHTS_MONTH</td>
#       <td id="T_b0715_row4_col1" class="data row4 col1" >0.031865</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_b0715_row5_col0" class="data row5 col0" >PRCP</td>
#       <td id="T_b0715_row5_col1" class="data row5 col1" >0.028739</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_b0715_row6_col0" class="data row6 col0" >DEST_AIRPORT_ID</td>
#       <td id="T_b0715_row6_col1" class="data row6 col1" >0.028273</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b0715_row7_col0" class="data row7 col0" >AIRLINE_FLIGHTS_MONTH</td>
#       <td id="T_b0715_row7_col1" class="data row7 col1" >0.027755</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_b0715_row8_col0" class="data row8 col0" >PLANE_AGE</td>
#       <td id="T_b0715_row8_col1" class="data row8 col1" >0.027295</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_b0715_row9_col0" class="data row9 col0" >DAY_OF_WEEK</td>
#       <td id="T_b0715_row9_col1" class="data row9 col1" >0.025532</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row10" class="row_heading level0 row10" >0</th>
#       <td id="T_b0715_row10_col0" class="data row10 col0" >MONTH</td>
#       <td id="T_b0715_row10_col1" class="data row10 col1" >0.024182</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row11" class="row_heading level0 row11" >3</th>
#       <td id="T_b0715_row11_col0" class="data row11 col0" >DISTANCE_GROUP</td>
#       <td id="T_b0715_row11_col1" class="data row11 col1" >0.021449</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row12" class="row_heading level0 row12" >9</th>
#       <td id="T_b0715_row12_col0" class="data row12 col0" >AVG_MONTHLY_PASS_AIRPORT</td>
#       <td id="T_b0715_row12_col1" class="data row12 col1" >0.020952</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row13" class="row_heading level0 row13" >5</th>
#       <td id="T_b0715_row13_col0" class="data row13 col0" >NUMBER_OF_SEATS</td>
#       <td id="T_b0715_row13_col1" class="data row13 col1" >0.020679</td>
#     </tr>
#     <tr>
#       <th id="T_b0715_level0_row14" class="row_heading level0 row14" >10</th>
#       <td id="T_b0715_row14_col0" class="data row14 col0" >AVG_MONTHLY_PASS_AIRLINE</td>
#       <td id="T_b0715_row14_col1" class="data row14 col1" >0.008989</td>
#     </tr>
#   </tbody>
# </table>
